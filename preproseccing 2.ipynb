# %%
import pandas as pd

# %%
gnaq=pd.read_table('gnaq.tsv')

# %%
gnaq.head()
# Out:
#                                    Study of Origin        Sample ID  \
# 0  Skin Cutaneous Melanoma (TCGA, PanCancer Atlas)  TCGA-ER-A2NF-06
# 1  Skin Cutaneous Melanoma (TCGA, PanCancer Atlas)  TCGA-ER-A2NF-01
# 2  Skin Cutaneous Melanoma (TCGA, PanCancer Atlas)  TCGA-RP-A690-06
# 3           Uveal Melanoma (TCGA, PanCancer Atlas)  TCGA-V4-A9F8-01
# 4           Uveal Melanoma (TCGA, PanCancer Atlas)  TCGA-V4-A9EE-01
#
#        Cancer Type Cancer Type Detailed Protein Change  \
# 0         Melanoma   Cutaneous Melanoma          Q209P
# 1         Melanoma   Cutaneous Melanoma          Q209P
# 2         Melanoma   Cutaneous Melanoma          Q209P
# 3  Ocular Melanoma       Uveal Melanoma          Q209P
# 4  Ocular Melanoma       Uveal Melanoma          Q209P
#
#                                           Annotation  \
# 0  OncoKB: Likely Oncogenic, level NA, resistance...
# 1  OncoKB: Likely Oncogenic, level NA, resistance...
# 2  OncoKB: Likely Oncogenic, level NA, resistance...
# ...

# %%
my_dict={}
gnaq_uveal_filter=gnaq[gnaq['Cancer Type Detailed']=='Uveal Melanoma']
s_Id=gnaq_uveal_filter['Sample ID']

for i in s_Id:
    my_dict[i]=[]

# %%
my_dict['TCGA-V4-A9F0-01']=['Q209L',
'Q456Rfs*115',
'D322H',
'M343T',
'V614L',
'E38D',
'I244M',
'W9*',
'Q390Dfs*27',
]

my_dict['TCGA-V4-A9EA-01']=['Q209L'
'R625C',
'G1594R',
'G1686S',
'A536T',
'M34V',
'R98Q',
'R491Q',
'Y197H',
]

my_dict['TCGA-VD-A8K7-01']=['Q209L',
'R7616W',
'H31R',
'C628*',

]

my_dict['TCGA-WC-AA9E-01']=['Q209L',
'R625H',
'R166H',
'I1276F',
'R268Q',
'V385M',
'C317S',
'Q1036E',
'A124V',
'E166K',
'V109A',
'T1304S',
'A67Qfs*53',
'W575L',
'X347_splice',
]

my_dict['TCGA-V4-A9EL-01']=['Q209L',
'P3411S',
'Y86*',
'V444I',
'X245_splice',
'P645Lfs*22',

]

my_dict['TCGA-WC-A880-01']=['Q209L',
'G6D',
'S121R',
'G5022S',
'M304L',
'P903L',
'N661I',
'A1405V',
'P719L',

]

my_dict['TCGA-V4-A9E7-01']=['Q209L',
'A922V',
'I71V',
'S544I',
'Q412L',
'S278F',
'S805N',
'A187T',
'G4331V',
'A772V',
'A669V',
'W515C',
'L158Cfs*43',
'X358_splice',
'R55C',
'K285Rfs*68',


]

# %%
print(my_dict)
mydic1=my_dict.copy()
# Out:
# {'TCGA-V4-A9F8-01': [], 'TCGA-V4-A9EE-01': [], 'TCGA-YZ-A983-01': [], 'TCGA-WC-A87U-01': [], 'TCGA-VD-A8KK-01': [], 'TCGA-VD-A8KE-01': [], 'TCGA-V4-A9EX-01': [], 'TCGA-WC-A87T-01': [], 'TCGA-VD-A8K9-01': [], 'TCGA-WC-A885-01': [], 'TCGA-V4-A9E9-01': [], 'TCGA-V4-A9EK-01': [], 'TCGA-V4-A9EO-01': [], 'TCGA-V4-A9F4-01': [], 'TCGA-VD-AA8M-01': [], 'TCGA-VD-A8KM-01': [], 'TCGA-VD-AA8S-01': [], 'TCGA-V4-A9EZ-01': [], 'TCGA-V4-A9EC-01': [], 'TCGA-VD-AA8Q-01': [], 'TCGA-V4-A9F1-01': [], 'TCGA-V4-A9EW-01': [], 'TCGA-VD-A8KB-01': [], 'TCGA-VD-A8KN-01': [], 'TCGA-V4-A9EY-01': [], 'TCGA-V4-A9E5-01': [], 'TCGA-WC-A883-01': [], 'TCGA-VD-A8KO-01': ['Q209L', 'A131T', 'P551Qfs*19', 'K7_G8delinsR', 'L168Sfs*2', 'T8S', 'A851D', 'S291R', 'X930_splice'], 'TCGA-V4-A9F0-01': ['Q209L', 'Q456Rfs*115', 'D322H', 'M343T', 'V614L', 'E38D', 'I244M', 'W9*', 'Q390Dfs*27'], 'TCGA-V4-A9EM-01': [], 'TCGA-V4-A9EA-01': ['Q209LR625C', 'G1594R', 'G1686S', 'A536T', 'M34V', 'R98Q', 'R491Q', 'Y197H'], 'TCGA-VD-A8K7-01': ['Q2
# ...
